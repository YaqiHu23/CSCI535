# %%
from google.colab import drive
import os
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.chdir('/content/drive/MyDrive/USC_Course/Multimodal_Probabilistic_Learning_of_Human_CSCI535/Group_Project/emotalkingface-main')

# %%
# !pip install visdom
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 6.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for visdom: filename=visdom-0.2.4-py3-none-any.whl size=1408195 sha256=2d83f7b482b552b82fc6e99b3d285b50124f50e2eb0c004997290b7088075ae1
#   Stored in directory: /root/.cache/pip/wheels/42/29/49/5bed207bac4578e4d2c0c5fc0226bfd33a7e2953ea56356855
# Successfully built visdom
# ...

# %% [markdown]
# Generate Examples

# %%
# !python generate.py -im ./data/image_samples/img01.png -is ./data/speech_samples/speech01.wav -m ./model/ -o ./results/
# Out:
# tensor([[1., 0., 0., 0., 0., 0.]])
# (63, 128, 128, 3) True
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %% [markdown]
# Try our extracted images and wav

# %%
# !python generate.py -im ../100_video_frames/VCslbP0mgZI_16/frame_00024.png -is ../100_wav/VCslbP0mgZI_16.wav -m ./model/ -o ./results_Our/num_10/
# Out:
# tensor([[1., 0., 0., 0., 0., 0.]])
# (46, 128, 128, 3) True
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %% [markdown]
# Pre-train Our models

# %% [markdown]
# Check whether we have the data or not

# %%
# os.chdir('/content/drive/MyDrive/USC_Course/Multimodal_Probabilistic_Learning_of_Human_CSCI535/Group_Project/emotalkingface-main/val_hdf5_folder')
# !ls
# os.chdir('/content/drive/MyDrive/USC_Course/Multimodal_Probabilistic_Learning_of_Human_CSCI535/Group_Project/emotalkingface-main')

# %% [markdown]
# Train the model

# %%
# !python train.py -i ./train_hdf5_folder/ -v ./val_hdf5_folder/ -o ./models/mde/ --pre_train 1 --disc_emo 1 --lr_emo 1e-4
# Out:
# 2024-04-21 19:25:04.836542: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-21 19:25:04.836602: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-21 19:25:04.838005: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-21 19:25:05.876986: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Cuda device available:  True
# Num files:  1757
# /usr/local/lib/python3.10/dist-packages/albumentations/augmentations/transforms.py:1258: FutureWarning: This class has been deprecated. Please use RandomBrightnessContrast
# ...

# %%
# !python train.py -i ./train_hdf5_folder/ -v ./val_hdf5_folder/ -o ./models/pre_gen/ --lr_g 1e-4
# Out:
# 2024-04-21 04:10:48.143398: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-21 04:10:48.143458: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-21 04:10:48.145083: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-21 04:10:49.387564: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Cuda device available:  True
# Num files:  1757
# /usr/local/lib/python3.10/dist-packages/albumentations/augmentations/transforms.py:1258: FutureWarning: This class has been deprecated. Please use RandomBrightnessContrast
# ...

# %%
# !python train.py -i ./train_hdf5_folder/ -v ./val_hdf5_folder/ -o ./models/tface_emo/ -m ./models/pre_gen/inter/ -mde ./models/mde/inter/ --disc_frame 0.01 --disc_emo 0.001
# Out:
# 2024-04-21 04:21:00.260229: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-21 04:21:00.260311: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-21 04:21:00.262226: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-21 04:21:01.305895: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Cuda device available:  True
# Num files:  1757
# /usr/local/lib/python3.10/dist-packages/albumentations/augmentations/transforms.py:1258: FutureWarning: This class has been deprecated. Please use RandomBrightnessContrast
# ...
