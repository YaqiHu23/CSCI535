# %%
# !ncu --version
# Out:
# NVIDIA (R) Nsight Compute Command Line Profiler
# Copyright (c) 2018-2024 NVIDIA Corporation
# Version 2024.2.1.0 (build 34372528) (public-release)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pip install jiwer librosa datasets transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 37.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 16.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 16.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 95.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 17.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !python train_ravdess_model.py
# Out:
# A classification problem with 8 classes: ['angry', 'calm', 'disgust', 'fearful', 'happy', 'neutral', 'sad', 'surprised']
# 2025-02-04 22:29:27.463560: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1738708167.487022    1843 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1738708167.498375    1843 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-04 22:29:27.521114: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
# !ncu --set full --target-processes all --export training_report python train_ravdess_model.py
# Out:
# A classification problem with 8 classes: ['angry', 'calm', 'disgust', 'fearful', 'happy', 'neutral', 'sad', 'surprised']
# 2025-02-04 22:46:48.980309: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1738709209.001855    6396 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1738709209.009538    6396 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-04 22:46:49.032154: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
# !ncu --import training_report.ncu-rep --print-summary per-gpu --export /content/summary.txt

# %%
# !cp /content/training_report.csv /content/drive/MyDrive/CS535_preprocessing/wav_csv

# %%
# !wget https://developer.nvidia.com/downloads/assets/tools/secure/nsight-systems/2025_1/NsightSystems-linux-cli-public-2025.1.1.103-3542797.deb
# Out:
# --2025-02-05 00:03:32--  https://developer.nvidia.com/downloads/assets/tools/secure/nsight-systems/2025_1/NsightSystems-linux-cli-public-2025.1.1.103-3542797.deb
# Resolving developer.nvidia.com (developer.nvidia.com)... 184.28.235.56, 184.28.235.50
# Connecting to developer.nvidia.com (developer.nvidia.com)|184.28.235.56|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://developer.download.nvidia.com/assets/tools/secure/nsight-systems/2025_1/NsightSystems-linux-cli-public-2025.1.1.103-3542797.deb?__token__=exp=1738714412~hmac=6c41700d29738a72c5b56f5239ac85e3fdb10b9ac2d1bde20c3f1f1ffcb37392 [following]
# --2025-02-05 00:03:32--  https://developer.download.nvidia.com/assets/tools/secure/nsight-systems/2025_1/NsightSystems-linux-cli-public-2025.1.1.103-3542797.deb?__token__=exp=1738714412~hmac=6c41700d29738a72c5b56f5239ac85e3fdb10b9ac2d1bde20c3f1f1ffcb37392
# ...

# %%
# !dpkg -i /content/NsightSystems-linux-cli-public-2025.1.1.103-3542797.deb
# Out:
# Selecting previously unselected package nsight-systems-cli-2025.1.1.
# (Reading database ... 124926 files and directories currently installed.)
# Preparing to unpack .../NsightSystems-linux-cli-public-2025.1.1.103-3542797.deb ...
# Unpacking nsight-systems-cli-2025.1.1 (2025.1.1.103-251135427971v0) ...
# Setting up nsight-systems-cli-2025.1.1 (2025.1.1.103-251135427971v0) ...
# update-alternatives: using /opt/nvidia/nsight-systems-cli/2025.1.1/target-linux-x64/nsys to provide /usr/local/bin/nsys (nsys) in auto mode

# %%
# !nsys profile -o training_nsys_report python train_ravdess_model.py
# Out:
# WARNING: Device-side CUDA Event completion trace is currently enabled.
#          This may increase runtime overhead and the likelihood of false
#          dependencies across CUDA Streams. If you wish to avoid this, please
#          disable the feature with --cuda-event-trace=false.
# ...
# 2025-02-05 00:04:22.192035: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1738713862.375588   59903 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1738713862.429629   59903 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !cp /content/training_nsys_report.nsys-rep /content/drive/MyDrive/CS535_preprocessing/wav_csv
